# %%
import zarr

data = zarr.open_group("scr_mk27/fgk.zarr")

# %%
[k for k in data.keys()]
# Out:
# ['spectra']

# %%
data.tree()
# Out:
# /
# └── spectra
#     ├── FEROS
#     │   ├── HD16160
#     │   │   └── HD16160_0.fits
#     │   │       ├── error (189649,) float32
#     │   │       ├── flux (189649,) float32
#     │   │       ├── hdr0_json () object
#     │   │       ├── hdr1_json () object
#     │   │       └── wavelength (189649,) float64
#     │   ├── HD22484
#     │   │   ├── HD22484_18.fits
#     │   │   │   ├── error (189657,) float32
#     │   │   │   ├── flux (189657,) float32
#     │   │   │   ├── hdr0_json () object
#     │   │   │   ├── hdr1_json () object
#     │   │   │   └── wavelength (189657,) float64
#     │   │   ├── HD22484_ivoesoorgIDADP2016-09-20T120337451.fits
#     │   │   │   ├── error (189659,) float32
#     │   │   │   ├── flux (189659,) float32
#     │   │   │   ├── hdr0_json () object
#     │   │   │   ├── hdr1_json () object
#     │   │   │   └── wavelength (189659,) float64
#     │   │   └── HD22484_ivoesoorgIDADP2020-10-15T095347429.fits
# ...
