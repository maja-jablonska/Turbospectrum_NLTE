# %%
import numpy as np  
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# %%
import sys
import os
# Add scripts directory to path to allow import
sys.path.append(os.path.abspath('scripts'))

from turbospectrum_utils import read_spectrum

# %%
ROOT = "/Users/mjablons/Documents/Turbospectrum_NLTE"


spec1 = read_spectrum('config_test/p2500_g+3.0_m0.0_t01_st_z+0.00_a+0.00_c+0.00_n+0.00_o+0.00_r+0.00_s+0.00.spec')

spec2 = read_spectrum('config_test_hline/p2500_g+3.0_m0.0_t01_st_z+0.00_a+0.00_c+0.00_n+0.00_o+0.00_r+0.00_s+0.00.spec')

spec3 = read_spectrum('config_test_feh/p2500_g+3.0_m0.0_t01_st_z+0.00_a+0.00_c+0.00_n+0.00_o+0.00_r+0.00_s+0.00.spec')
spec4 = read_spectrum('config_test_feh/p3500_g+3.0_m0.0_t01_st_z+0.00_a+0.00_c+0.00_n+0.00_o+0.00_r+0.00_s+0.00.spec')

# %%
spec1.keys()
# Out:
# dict_keys(['mode', 'wavelength', 'flux_norm', 'flux_abs'])

# %%
import cmasher as cmr
plt.plot(spec1['wavelength'], spec1['flux_norm'])

# %%
plt.plot(spec2['wavelength'], spec2['flux_norm'])

# %%
plt.plot(spec3['wavelength'], spec3['flux_norm'])

# %%
plt.plot(spec4['wavelength'], spec4['flux_norm'])
