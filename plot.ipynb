# %%
import numpy as np  
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# %%
import sys
import os
# Add scripts directory to path to allow import
sys.path.append(os.path.abspath('scripts'))

from turbospectrum_utils import read_spectrum

# %%
spec = read_spectrum('/Users/mjablons/Documents/Turbospectrum_NLTE/spectra/p2500_g+3.0_m0.0_t01_st_z+0.00_a+0.00_c+0.00_n+0.00_o+0.00_r+0.00_s+0.00.intensity.spec')

# %%
spec.keys()
# Out:
# dict_keys(['mode', 'wavelength', 'flux_norm', 'flux_abs', 'mu_points', 'intensity_abs', 'intensity_norm'])

# %%
import cmasher as cmr

for mu in spec['mu_points']:
    plt.plot(spec['wavelength'], spec['intensity_abs'][mu], color=cmr.gem(mu))
