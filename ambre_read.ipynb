# %%
import zarr

spectra = zarr.open("ambre.zarr", mode="r")
print(spectra)
# Out:
# <Group file://ambre.zarr>

# %%
len(spectra)
# Out:
# 17

# %%
len(spectra['flux'][2])
# Out:
# 450001

# %%
print("Number of spectra stored:", spectra['flux'].shape[0])
# Out:
# Number of spectra stored: 3
